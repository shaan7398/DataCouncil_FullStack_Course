# %%
age = int(input("Please enter your age"))

if(age >=18):
    print("You are eligible to Vote")
else:
    print("Sorry ! You are not eligible to Vote")
# Out:
# Please enter your age 15
# Sorry ! You are not eligible to Vote

# %%
num = int(input("Please enter any number"))

if(num <0):
    print("It is negative number")
elif(num >0):
    print("It is positive number")
else:
    print("0")
# Out:
# Please enter any number 0
# 0

# %%
Marks = int(input("Enter your Marks"))

if(Marks >= 90):
    print("A")
elif(Marks >= 80 and Marks<90):
    print("B")
elif(Marks >= 70 and Marks<80):
    print("C")
else:
    print("Fail")
# Out:
# Enter your Marks 89
# B

# %%
Num = int(input("Enter any number"))

if(Num%2 == 0):
    print("Even number")
else:
    print("Odd Number")
# Out:
# Enter any number 7
# Odd Number

# %%
year = int(input("Enter the year"))

if(year % 4 == 0 and year%100 !=0):
    print("It is Leap year")
elif(year%400 == 0):
    print("It is Leap year")
else:
    print("Not a Leap year")
# Out:
# Enter the year 2020
# It is Leap year

# %%
Num1 = int(input("Enter Number 1"))
Num2 = int(input("Enter Number 2"))
Num3 = int(input("Enter Number 3"))

if((Num1>Num2) and (Num1>Num3)):
    print(f"Largest Number is {Num1}")
elif((Num2>Num1) and (Num2>Num3)):
    print(f"Largest Number is {Num2}")
else:
    print(f"Largest Number is {Num3}")
# Out:
# Enter Number 1 68
# Enter Number 2 58
# Enter Number 3 47
# Largest Number is 68

# %%
price = int(input("Please enter price of the item"))
discounted_price = 0

if(price > 100):
    discounted_price = price - (0.2*price)
    print(f"You have got 20% discount on {price} and total after discount is {discounted_price}")
elif(price>=50 and price <= 100):
    discounted_price = price - (0.5*price)
    print(f"You have got 50% discount on {price} and total after discount is {discounted_price}")
else:
    discounted_price = price
    print(f"Sorry no discount below 50$, your total is {price}")
# Out:
# Please enter price of the item 76
# You have got 50% discount on 76 and total after discount is 38.0

# %%
N = int(input("Enter number till which total to be calculated"))

for i in r
    print(i+i)
# Out:
# Enter number till which total to be calculated 7
# 0
# 2
# 4
# 6
# 8
# 10
# 12

# %%
Num = int(input("Enter any number"))
for i in range(1,11):
    print(Num*i)
# Out:
# Enter any number 7
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70

# %%
l = [1,2,3,4,5]

for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [raw]
# num = int(input("Please enter number to find its factorial"))
# factorial = 1
#
# for i in range(1,num+1):
#
#     factorial = factorial * i
# print(factorial)

# %% [markdown]
# # Ask to Sir

# %%
name = input("Enter any word")

reversed_s = "" #what is the logic

for i in name:
    reversed_s = i + reversed_s
print(reversed_s) #how does print out loop plays the role
# Out:
# Enter any word Shaan
# naahS

# %% [markdown]
# Not able to find logic for Prime Numbers

# %%
N = int(input("Pattern upto"))

for i in range(1,N+1):
    print(i * '$')
# Out:
# Pattern upto 7
# $
# $$
# $$$
# $$$$
# $$$$$
# $$$$$$
# $$$$$$$

# %%
N = int(input("Please enter any number"))
eventot = 0
oddtot = 0

for i in range(1,N+1):
    if(i%2 == 0):
        eventot = eventot + i
    else:
        oddtot = oddtot + i
print(f"The sum of even numbers till {N} is {eventot}")
print(f"The sum of odd numbers till {N} is {oddtot}")
# Out:
# Please enter any number 10
# The sum of even numbers till 10 is 30
# The sum of odd numbers till 10 is 25

# %%
Num = 15
total = 0 

while Num >= 0:
    total = total + Num
    Num = Num - 1
print(total)
# Out:
# 120

# %%
N = 0

while N != 7:
    print(f"You have entered Wrong Number {N}")
    N = int(input("Try again wit any number between 1-10"))
print("Correct Number !")
# Out:
# You have entered Wrong Number 0
# Try again wit any number between 1-10 78
# You have entered Wrong Number 78
# Try again wit any number between 1-10 65
# You have entered Wrong Number 65
# Try again wit any number between 1-10 8
# You have entered Wrong Number 8
# Try again wit any number between 1-10 7
# Correct Number !

# %%
N = 1
Sum = 0

while N != 0:
    Sum = Sum + N
    N = int(input("Enter next number"))
    print("Press 0 to stop calculation")
print(Sum-1)
# Out:
# Enter next number 7
# Press 0 to stop calculation
# Enter next number 7
# Press 0 to stop calculation
# Enter next number 7
# Press 0 to stop calculation
# Enter next number 7
# Press 0 to stop calculation
# Enter next number 7
# Press 0 to stop calculation
# Enter next number 0
# Press 0 to stop calculation
# 35
